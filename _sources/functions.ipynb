# %% [markdown]
# # Functions

# %% [markdown]
# <img src ="https://github.com/williamedwardhahn/Artificial_Life/raw/main/images/1.png" height="50">

# %%
def x_squared(x):
    return x**2

# %%
def big_number():
    return 2**1234

# %%
big_number()
# Out:
# 
